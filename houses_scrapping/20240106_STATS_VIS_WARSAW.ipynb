# %% [markdown]
# # WARSAW

# %% [markdown]
# ### BASIC STATS

# %%
import os
import subprocess

# prepering directories
path = os.getcwd()
# subfolders
input_dir = os.path.join(path, 'inputs')
output_dir = os.path.join(path, 'outputs')

# open folder
subprocess.Popen(f'explorer "{output_dir}"')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import matplotlib.dates as mdates
from matplotlib.lines import Line2D
from matplotlib.dates import DateFormatter

import seaborn as sns

# to supres Pandas warnings
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
plt.style.use("fivethirtyeight")
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\Ukasz\Anaconda3\envs\geopandas\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution

# %%
# current the current color palette
print(sns.color_palette().as_hex())
sns.color_palette()
# Out:
# ['#008fd5', '#fc4f30', '#e5ae38', '#6d904f', '#8b8b8b', '#810f7c']
# [(0.0, 0.5607843137254902, 0.8352941176470589),
#  (0.9882352941176471, 0.30980392156862746, 0.18823529411764706),
#  (0.8980392156862745, 0.6823529411764706, 0.2196078431372549),
#  (0.42745098039215684, 0.5647058823529412, 0.30980392156862746),
#  (0.5450980392156862, 0.5450980392156862, 0.5450980392156862),
#  (0.5058823529411764, 0.058823529411764705, 0.48627450980392156)]

# %%
data = pd.read_csv(os.path.join(os.getcwd(), 'outputs', 'warszawa_page_all_pages_20240107194658.csv'))

# %%
data.shape
# Out:
# (11982, 8)

# %%
data.head(1)
# Out:
#                                 free_text  \
# 0  Mieszkanie z potencjałem inwestycyjnym
#
#                                              address         price  \
# 0  Mieszkanie na sprzedaż: ul. Obozowa, Młynów, W...  1 431 167 zł
#
#     price_meter     rooms      area                 more  \
# 0  18 100 zł/m²  4 pokoje  79,07 m²  Biuro nieruchomości
#
#                                             add_link
# 0  /pl/oferta/mieszkanie-z-potencjalem-inwestycyj...

# %% [markdown]
# #### Cleaning the 'price' column

# %%
data['price'] = data['price'].str.replace(u'\xa0', u' ')
data['price'] = data['price'].str.replace(' ', '', regex=True)
data['price'] = data['price'].str.replace('zł', '', regex=True)
data['price'] = data['price'].str.replace(',', '.', regex=True)
# drop nan
data = data[data['price'].notna()]
data['price'] = pd.to_numeric(data['price'])

# %% [markdown]
# #### Cleaning the 'price_meter' column

# %%
data['price_meter'] = data['price_meter'].str.replace(u'\xa0', u' ')
data['price_meter'] = data['price_meter'].str.replace(' ', '', regex=True)
data['price_meter'] = data['price_meter'].str.replace('zł/m²', '', regex=True)
data['price_meter'] = data['price_meter'].str.replace(',', '.', regex=True)
# drop nan
data = data[data['price_meter'].notna()]
data['price_meter'] = pd.to_numeric(data['price_meter'])

# %% [markdown]
# #### Cleaning the 'area' column

# %%
data['area'] = data['area'].str.replace(u'\xa0', u' ')
data['area'] = data['area'].str.replace(' ', '', regex=True)
data['area'] = data['area'].str.replace('m²', '', regex=True)
data['area'] = data['area'].str.replace(',', '.', regex=True)
# drop nan
data = data[data['area'].notna()]
data['area'] = pd.to_numeric(data['area'])

# %% [markdown]
# ## DATA BEFORE REMOVING OUTLIERS
# ### Price

# %%
data['rooms_umber'] = data['rooms'].str.extract('(\d+)').astype(int)
df = data.describe().astype(int)
df
# Out:
#            price  price_meter  area  rooms_umber
# count       8519         8519  8519         8519
# mean     1209066        17772    66            2
# std      1610578         7170    48            1
# min       188500         2211    13            1
# 25%       690000        13738    42            2
# 50%       881328        16667    56            3
# 75%      1265456        20312    75            3
# max    100000000       295858  2300           10

# %%
sns.displot(data, x="price", height=4, aspect=4, bins=list(range(0, int(max(data['price'])), 100000)))
plt.xticks(list(range(0, int(max(data['price'])), 100000)), rotation='vertical')
plt.title("Price distribution [100 000 zl bin breaks] of the entire dataset\n", fontweight='bold')
plt.savefig('WARSAW_price_distribution.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# **Cutting data** - left cut bins

# %%
r = range(0, int(max(data['price'])) + 100000, 100000)

data['LCBINS_100k'] = pd.cut(data['price'], r, right=False, labels=False)
def create_label(row):
    return str(row['LCBINS_100k'] * 100) + 'k - ' + str((row['LCBINS_100k'] + 1) * 100) +'k'

data['BINS_100k'] = data.apply(create_label, axis=1)
data.head(3)
# Out:
#                                           free_text  \
# 0            Mieszkanie z potencjałem inwestycyjnym
# 1     Przestronne mieszkanie z tarasem na Grochowie
# 2  3 pokojowe mieszkanie z klimatyzacją dla rodziny
#
#                                              address      price  price_meter  \
# 0  Mieszkanie na sprzedaż: ul. Obozowa, Młynów, W...  1431167.0        18100
# 1  Mieszkanie na sprzedaż: ul. Nizinna, Grochów, ...  1828000.0        14062
# 2  Mieszkanie na sprzedaż: ul. Obrońców Tobruku, ...  1270000.0        17445
#
#       rooms    area                 more  \
# 0  4 pokoje   79.07  Biuro nieruchomości
# 1  3 pokoje  130.00  Biuro nieruchomości
# 2  3 pokoje   72.80  Biuro nieruchomości
#
#                                             add_link  rooms_umber  \
# 0  /pl/oferta/mieszkanie-z-potencjalem-inwestycyj...            4
# 1  /pl/oferta/przestronne-mieszkanie-z-tarasem-na...            3
# 2  /pl/oferta/3-pokojowe-mieszkanie-z-klimatyzacj...            3
#
#    LCBINS_100k          BINS_100k
# 0         14.0  1400.0k - 1500.0k
# 1         18.0  1800.0k - 1900.0k
# 2         12.0  1200.0k - 1300.0k

# %%
df = pd.pivot_table(data, 'price','LCBINS_100k', aggfunc=['count', 'min', 'max', 'median', 'mean']).astype(int)
df.sort_index(inplace=True)
df.style.bar(subset=["count"], color='#3ca7db')
# Out:
# <style type="text/css">
# #T_bdf4a_row0_col0, #T_bdf4a_row42_col0, #T_bdf4a_row51_col0, #T_bdf4a_row52_col0, #T_bdf4a_row53_col0, #T_bdf4a_row54_col0, #T_bdf4a_row62_col0, #T_bdf4a_row65_col0, #T_bdf4a_row70_col0, #T_bdf4a_row74_col0, #T_bdf4a_row77_col0, #T_bdf4a_row78_col0, #T_bdf4a_row80_col0, #T_bdf4a_row87_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3ca7db 0.1%, transparent 0.1%);
# }
# #T_bdf4a_row1_col0, #T_bdf4a_row43_col0, #T_bdf4a_row45_col0, #T_bdf4a_row63_col0, #T_bdf4a_row82_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3ca7db 0.4%, transparent 0.4%);
# }
# #T_bdf4a_row2_col0, #T_bdf4a_row16_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3ca7db 9.5%, transparent 9.5%);
# }
# #T_bdf4a_row3_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3ca7db 36.1%, transparent 36.1%);
# }
# #T_bdf4a_row4_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3ca7db 53.7%, transparent 53.7%);
# }
# #T_bdf4a_row5_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3ca7db 100.0%, transparent 100.0%);
# }
# #T_bdf4a_row6_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3ca7db 99.8%, transparent 99.8%);
# }
# #T_bdf4a_row7_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3ca7db 86.4%, transparent 86.4%);
# }
# #T_bdf4a_row8_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3ca7db 69.2%, transparent 69.2%);
# }
# #T_bdf4a_row9_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3ca7db 35.7%, transparent 35.7%);
# }
# #T_bdf4a_row10_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3ca7db 36.0%, transparent 36.0%);
# }
# #T_bdf4a_row11_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3ca7db 33.9%, transparent 33.9%);
# }
# #T_bdf4a_row12_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3ca7db 24.7%, transparent 24.7%);
# }
# #T_bdf4a_row13_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3ca7db 15.3%, transparent 15.3%);
# }
# #T_bdf4a_row14_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3ca7db 15.6%, transparent 15.6%);
# }
# #T_bdf4a_row15_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3ca7db 12.8%, transparent 12.8%);
# }
# #T_bdf4a_row17_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3ca7db 11.7%, transparent 11.7%);
# }
# #T_bdf4a_row18_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3ca7db 7.9%, transparent 7.9%);
# }
# #T_bdf4a_row19_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3ca7db 5.3%, transparent 5.3%);
# }
# #T_bdf4a_row20_col0, #T_bdf4a_row23_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3ca7db 4.7%, transparent 4.7%);
# }
# #T_bdf4a_row21_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3ca7db 4.9%, transparent 4.9%);
# }
# #T_bdf4a_row22_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3ca7db 3.4%, transparent 3.4%);
# }
# #T_bdf4a_row24_col0, #T_bdf4a_row27_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3ca7db 4.4%, transparent 4.4%);
# }
# #T_bdf4a_row25_col0, #T_bdf4a_row31_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3ca7db 2.5%, transparent 2.5%);
# }
# #T_bdf4a_row26_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3ca7db 2.4%, transparent 2.4%);
# }
# #T_bdf4a_row28_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3ca7db 3.0%, transparent 3.0%);
# }
# #T_bdf4a_row29_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3ca7db 1.7%, transparent 1.7%);
# }
# #T_bdf4a_row30_col0, #T_bdf4a_row35_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3ca7db 1.6%, transparent 1.6%);
# }
# #T_bdf4a_row32_col0, #T_bdf4a_row33_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3ca7db 1.8%, transparent 1.8%);
# }
# #T_bdf4a_row34_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3ca7db 2.6%, transparent 2.6%);
# }
# #T_bdf4a_row36_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3ca7db 0.6%, transparent 0.6%);
# }
# #T_bdf4a_row37_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3ca7db 0.9%, transparent 0.9%);
# }
# #T_bdf4a_row38_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3ca7db 2.8%, transparent 2.8%);
# }
# #T_bdf4a_row39_col0, #T_bdf4a_row40_col0, #T_bdf4a_row46_col0, #T_bdf4a_row47_col0, #T_bdf4a_row49_col0, #T_bdf4a_row50_col0, #T_bdf4a_row64_col0, #T_bdf4a_row79_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3ca7db 0.3%, transparent 0.3%);
# }
# #T_bdf4a_row41_col0, #T_bdf4a_row61_col0, #T_bdf4a_row75_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3ca7db 0.2%, transparent 0.2%);
# }
# #T_bdf4a_row44_col0, #T_bdf4a_row57_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3ca7db 0.7%, transparent 0.7%);
# }
# #T_bdf4a_row48_col0, #T_bdf4a_row58_col0, #T_bdf4a_row60_col0, #T_bdf4a_row76_col0, #T_bdf4a_row84_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3ca7db 0.5%, transparent 0.5%);
# }
# #T_bdf4a_row55_col0, #T_bdf4a_row56_col0, #T_bdf4a_row59_col0, #T_bdf4a_row66_col0, #T_bdf4a_row67_col0, #T_bdf4a_row68_col0, #T_bdf4a_row69_col0, #T_bdf4a_row71_col0, #T_bdf4a_row72_col0, #T_bdf4a_row73_col0, #T_bdf4a_row81_col0, #T_bdf4a_row83_col0, #T_bdf4a_row85_col0, #T_bdf4a_row86_col0, #T_bdf4a_row88_col0, #T_bdf4a_row89_col0, #T_bdf4a_row90_col0 {
#   width: 10em;
#   height: 80%;
# }
# </style>
# <table id="T_bdf4a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >min</th>
#       <th class="col_heading level0 col2" >max</th>
#       <th class="col_heading level0 col3" >median</th>
#       <th class="col_heading level0 col4" >mean</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th class="col_heading level1 col0" >price</th>
#       <th class="col_heading level1 col1" >price</th>
#       <th class="col_heading level1 col2" >price</th>
#       <th class="col_heading level1 col3" >price</th>
#       <th class="col_heading level1 col4" >price</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >LCBINS_100k</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bdf4a_level0_row0" class="row_heading level0 row0" >1.0</th>
#       <td id="T_bdf4a_row0_col0" class="data row0 col0" >2</td>
#       <td id="T_bdf4a_row0_col1" class="data row0 col1" >188500</td>
#       <td id="T_bdf4a_row0_col2" class="data row0 col2" >190000</td>
#       <td id="T_bdf4a_row0_col3" class="data row0 col3" >189250</td>
#       <td id="T_bdf4a_row0_col4" class="data row0 col4" >189250</td>
#     </tr>
#     <tr>
#       <th id="T_bdf4a_level0_row1" class="row_heading level0 row1" >2.0</th>
#       <td id="T_bdf4a_row1_col0" class="data row1 col0" >6</td>
#       <td id="T_bdf4a_row1_col1" class="data row1 col1" >210000</td>
#       <td id="T_bdf4a_row1_col2" class="data row1 col2" >299000</td>
#       <td id="T_bdf4a_row1_col3" class="data row1 col3" >242000</td>
#       <td id="T_bdf4a_row1_col4" class="data row1 col4" >251833</td>
#     </tr>
#     <tr>
#       <th id="T_bdf4a_level0_row2" class="row_heading level0 row2" >3.0</th>
#       <td id="T_bdf4a_row2_col0" class="data row2 col0" >111</td>
#       <td id="T_bdf4a_row2_col1" class="data row2 col1" >300000</td>
#       <td id="T_bdf4a_row2_col2" class="data row2 col2" >399900</td>
#       <td id="T_bdf4a_row2_col3" class="data row2 col3" >385581</td>

# %% [markdown]
# #### AREA

# %%
sns.displot(data, x="area", height=4, aspect=4, bins=list(range(0, int(max(data['area'])) + 10, 10)), color='#fc4f30' )
plt.xticks(list(range(0, int(max(data['area'])) + 10 , 10)), rotation='vertical')
plt.title("Property size [10m² bin breaks]\n", fontweight='bold')
plt.savefig('WARSAW_size_distribution.png', bbox_inches='tight')
plt.show()

# %%
r = range(0, int(max(data['area'])) + 10, 10)

data['LCBINS_10'] = pd.cut(data['area'], r, right=False, labels=False)
def create_label(row):
    return str(row['LCBINS_10'] * 10) + ' - ' + str((row['LCBINS_10'] + 1) * 10) + 'm²'

data['BINS_10'] = data.apply(create_label, axis=1)
data.head(3)
# Out:
#                                           free_text  \
# 0            Mieszkanie z potencjałem inwestycyjnym
# 1     Przestronne mieszkanie z tarasem na Grochowie
# 2  3 pokojowe mieszkanie z klimatyzacją dla rodziny
#
#                                              address      price  price_meter  \
# 0  Mieszkanie na sprzedaż: ul. Obozowa, Młynów, W...  1431167.0        18100
# 1  Mieszkanie na sprzedaż: ul. Nizinna, Grochów, ...  1828000.0        14062
# 2  Mieszkanie na sprzedaż: ul. Obrońców Tobruku, ...  1270000.0        17445
#
#       rooms    area                 more  \
# 0  4 pokoje   79.07  Biuro nieruchomości
# 1  3 pokoje  130.00  Biuro nieruchomości
# 2  3 pokoje   72.80  Biuro nieruchomości
#
#                                             add_link  rooms_umber  \
# 0  /pl/oferta/mieszkanie-z-potencjalem-inwestycyj...            4
# 1  /pl/oferta/przestronne-mieszkanie-z-tarasem-na...            3
# 2  /pl/oferta/3-pokojowe-mieszkanie-z-klimatyzacj...            3
#
#    LCBINS_100k          BINS_100k  LCBINS_10          BINS_10
# 0         14.0  1400.0k - 1500.0k        7.0    70.0 - 80.0m²
# 1         18.0  1800.0k - 1900.0k       13.0  130.0 - 140.0m²
# 2         12.0  1200.0k - 1300.0k        7.0    70.0 - 80.0m²

# %%
# create dictionary
values = data[['LCBINS_10', 'BINS_10']]
values = values.drop_duplicates(subset=['LCBINS_10'], keep='first').sort_values(by=['LCBINS_10'], ascending=True) 
d = pd.Series(values['BINS_10'].values,index=values['LCBINS_10']).to_dict()

df = pd.pivot_table(data, 'area','LCBINS_10', aggfunc=['count', 'min', 'max', 'median', 'mean']).astype(int)
df.sort_index(inplace=True)

df.index = [ d[k] for k in list(df.index)]
df.style.bar(subset=["count"], color='#fc4f30')
# Out:
# <style type="text/css">
# #T_dd913_row0_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#fc4f30 3.7%, transparent 3.7%);
# }
# #T_dd913_row1_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#fc4f30 24.8%, transparent 24.8%);
# }
# #T_dd913_row2_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#fc4f30 79.6%, transparent 79.6%);
# }
# #T_dd913_row3_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#fc4f30 92.5%, transparent 92.5%);
# }
# #T_dd913_row4_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#fc4f30 100.0%, transparent 100.0%);
# }
# #T_dd913_row5_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#fc4f30 70.1%, transparent 70.1%);
# }
# #T_dd913_row6_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#fc4f30 39.8%, transparent 39.8%);
# }
# #T_dd913_row7_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#fc4f30 29.2%, transparent 29.2%);
# }
# #T_dd913_row8_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#fc4f30 20.3%, transparent 20.3%);
# }
# #T_dd913_row9_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#fc4f30 16.7%, transparent 16.7%);
# }
# #T_dd913_row10_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#fc4f30 11.0%, transparent 11.0%);
# }
# #T_dd913_row11_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#fc4f30 9.2%, transparent 9.2%);
# }
# #T_dd913_row12_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#fc4f30 6.1%, transparent 6.1%);
# }
# #T_dd913_row13_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#fc4f30 4.0%, transparent 4.0%);
# }
# #T_dd913_row14_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#fc4f30 4.6%, transparent 4.6%);
# }
# #T_dd913_row15_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#fc4f30 2.7%, transparent 2.7%);
# }
# #T_dd913_row16_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#fc4f30 1.7%, transparent 1.7%);
# }
# #T_dd913_row17_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#fc4f30 1.5%, transparent 1.5%);
# }
# #T_dd913_row18_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#fc4f30 1.3%, transparent 1.3%);
# }
# #T_dd913_row19_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#fc4f30 0.7%, transparent 0.7%);
# }
# #T_dd913_row20_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#fc4f30 0.5%, transparent 0.5%);
# }
# #T_dd913_row21_col0, #T_dd913_row23_col0, #T_dd913_row32_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#fc4f30 0.3%, transparent 0.3%);
# }
# #T_dd913_row22_col0, #T_dd913_row25_col0, #T_dd913_row28_col0, #T_dd913_row29_col0, #T_dd913_row34_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#fc4f30 0.4%, transparent 0.4%);
# }
# #T_dd913_row24_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#fc4f30 0.6%, transparent 0.6%);
# }
# #T_dd913_row26_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#fc4f30 1.0%, transparent 1.0%);
# }
# #T_dd913_row27_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#fc4f30 0.2%, transparent 0.2%);
# }
# #T_dd913_row30_col0, #T_dd913_row33_col0, #T_dd913_row35_col0, #T_dd913_row36_col0, #T_dd913_row39_col0, #T_dd913_row40_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#fc4f30 0.1%, transparent 0.1%);
# }
# #T_dd913_row31_col0, #T_dd913_row37_col0, #T_dd913_row38_col0, #T_dd913_row41_col0, #T_dd913_row42_col0 {
#   width: 10em;
#   height: 80%;
# }
# </style>
# <table id="T_dd913_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >min</th>
#       <th class="col_heading level0 col2" >max</th>
#       <th class="col_heading level0 col3" >median</th>
#       <th class="col_heading level0 col4" >mean</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th class="col_heading level1 col0" >area</th>
#       <th class="col_heading level1 col1" >area</th>
#       <th class="col_heading level1 col2" >area</th>
#       <th class="col_heading level1 col3" >area</th>
#       <th class="col_heading level1 col4" >area</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd913_level0_row0" class="row_heading level0 row0" >10.0 - 20.0m²</th>
#       <td id="T_dd913_row0_col0" class="data row0 col0" >61</td>
#       <td id="T_dd913_row0_col1" class="data row0 col1" >13</td>
#       <td id="T_dd913_row0_col2" class="data row0 col2" >19</td>
#       <td id="T_dd913_row0_col3" class="data row0 col3" >16</td>
#       <td id="T_dd913_row0_col4" class="data row0 col4" >17</td>
#     </tr>
#     <tr>
#       <th id="T_dd913_level0_row1" class="row_heading level0 row1" >20.0 - 30.0m²</th>
#       <td id="T_dd913_row1_col0" class="data row1 col0" >401</td>
#       <td id="T_dd913_row1_col1" class="data row1 col1" >20</td>
#       <td id="T_dd913_row1_col2" class="data row1 col2" >29</td>
#       <td id="T_dd913_row1_col3" class="data row1 col3" >27</td>
#       <td id="T_dd913_row1_col4" class="data row1 col4" >26</td>
#     </tr>
#     <tr>
#       <th id="T_dd913_level0_row2" class="row_heading level0 row2" >30.0 - 40.0m²</th>
#       <td id="T_dd913_row2_col0" class="data row2 col0" >1286</td>
#       <td id="T_dd913_row2_col1" class="data row2 col1" >30</td>
#       <td id="T_dd913_row2_col2" class="data row2 col2" >39</td>
#       <td id="T_dd913_row2_col3" class="data row2 col3" >36</td>
#       <td id="T_dd913_row2_col4" class="data row2 col4" >35</td>
#     </tr>
#     <tr>
#       <th id="T_dd913_level0_row3" class="row_heading level0 row3" >40.0 - 50.0m²</th>
#       <td id="T_dd913_row3_col0" class="data row3 col0" >1494</td>
#       <td id="T_dd913_row3_col1" class="data row3 col1" >40</td>
#       <td id="T_dd913_row3_col2" class="data row3 col2" >49</td>
#       <td id="T_dd913_row3_col3" class="data row3 col3" >45</td>
#       <td id="T_dd913_row3_col4" class="data row3 col4" >45</td>
#     </tr>
#     <tr>
#       <th id="T_dd913_level0_row4" class="row_heading level0 row4" >50.0 - 60.0m²</th>
#       <td id="T_dd913_row4_col0" class="data row4 col0" >1615</td>
#       <td id="T_dd913_row4_col1" class="data row4 col1" >50</td>
#       <td id="T_dd913_row4_col2" class="data row4 col2" >59</td>
#       <td id="T_dd913_row4_col3" class="data row4 col3" >55</td>
#       <td id="T_dd913_row4_col4" class="data row4 col4" >54</td>
#     </tr>
#     <tr>
#       <th id="T_dd913_level0_row5" class="row_heading level0 row5" >60.0 - 70.0m²</th>
#       <td id="T_dd913_row5_col0" class="data row5 col0" >1133</td>
#       <td id="T_dd913_row5_col1" class="data row5 col1" >60</td>
#       <td id="T_dd913_row5_col2" class="data row5 col2" >69</td>
#       <td id="T_dd913_row5_col3" class="data row5 col3" >64</td>
#       <td id="T_dd913_row5_col4" class="data row5 col4" >64</td>
#     </tr>
#     <tr>
#       <th id="T_dd913_level0_row6" class="row_heading level0 row6" >70.0 - 80.0m²</th>
#       <td id="T_dd913_row6_col0" class="data row6 col0" >643</td>
#       <td id="T_dd913_row6_col1" class="data row6 col1" >70</td>
#       <td id="T_dd913_row6_col2" class="data row6 col2" >79</td>
#       <td id="T_dd913_row6_col3" class="data row6 col3" >74</td>
#       <td id="T_dd913_row6_col4" class="data row6 col4" >74</td>
#     </tr>
#     <tr>
#       <th id="T_dd913_level0_row7" class="row_heading level0 row7" >80.0 - 90.0m²</th>
#       <td id="T_dd913_row7_col0" class="data row7 col0" >472</td>
#       <td id="T_dd913_row7_col1" class="data row7 col1" >80</td>
#       <td id="T_dd913_row7_col2" class="data row7 col2" >89</td>
#       <td id="T_dd913_row7_col3" class="data row7 col3" >84</td>
#       <td id="T_dd913_row7_col4" class="data row7 col4" >84</td>
#     </tr>
#     <tr>
#       <th id="T_dd913_level0_row8" class="row_heading level0 row8" >90.0 - 100.0m²</th>

# %% [markdown]
# ### Price per square metre

# %%
sns.displot(data, x="price_meter", height=4, aspect=4, bins=list(range(0, int(max(data['price_meter'])) + 1000, 1000)), color='#e5ae38' )
plt.xticks(list(range(0, int(max(data['price_meter'])) + 1000 , 1000)), rotation='vertical')
plt.title("Price per square metre [1000zl bin breaks]\n", fontweight='bold')
plt.savefig('WARSAW_price_meter_distribution.png', bbox_inches='tight')
plt.show()

# %%
r = range(0, int(max(data['price_meter'])) + 1000, 1000)

data['LCBINS_1000SQ'] = pd.cut(data['price_meter'], r, right=False, labels=False)
def create_label(row):
    return str(row['LCBINS_1000SQ'] * 1000) + ' - ' + str((row['LCBINS_1000SQ'] + 1) * 1000) + ' zl/m²'

data['BINS_10SQ'] = data.apply(create_label, axis=1)
data.head(3)
# Out:
#                                           free_text  \
# 0            Mieszkanie z potencjałem inwestycyjnym
# 1     Przestronne mieszkanie z tarasem na Grochowie
# 2  3 pokojowe mieszkanie z klimatyzacją dla rodziny
#
#                                              address      price  price_meter  \
# 0  Mieszkanie na sprzedaż: ul. Obozowa, Młynów, W...  1431167.0        18100
# 1  Mieszkanie na sprzedaż: ul. Nizinna, Grochów, ...  1828000.0        14062
# 2  Mieszkanie na sprzedaż: ul. Obrońców Tobruku, ...  1270000.0        17445
#
#       rooms    area                 more  \
# 0  4 pokoje   79.07  Biuro nieruchomości
# 1  3 pokoje  130.00  Biuro nieruchomości
# 2  3 pokoje   72.80  Biuro nieruchomości
#
#                                             add_link  rooms_umber  \
# 0  /pl/oferta/mieszkanie-z-potencjalem-inwestycyj...            4
# 1  /pl/oferta/przestronne-mieszkanie-z-tarasem-na...            3
# 2  /pl/oferta/3-pokojowe-mieszkanie-z-klimatyzacj...            3
#
#    LCBINS_100k          BINS_100k  LCBINS_10          BINS_10  LCBINS_1000SQ  \
# 0         14.0  1400.0k - 1500.0k        7.0    70.0 - 80.0m²             18
# 1         18.0  1800.0k - 1900.0k       13.0  130.0 - 140.0m²             14
# 2         12.0  1200.0k - 1300.0k        7.0    70.0 - 80.0m²             17
#
#              BINS_10SQ
# 0  18000 - 19000 zl/m²
# 1  14000 - 15000 zl/m²
# 2  17000 - 18000 zl/m²

# %%
# create dictionary
values = data[['LCBINS_1000SQ', 'BINS_10SQ']]
values = values.drop_duplicates(subset=['LCBINS_1000SQ'], keep='first').sort_values(by=['LCBINS_1000SQ'], ascending=True) 
d = pd.Series(values['BINS_10SQ'].values,index=values['LCBINS_1000SQ']).to_dict()

df = pd.pivot_table(data, 'price_meter','LCBINS_1000SQ', aggfunc=['count', 'min', 'max', 'median', 'mean']).astype(int)
df.sort_index(inplace=True)

df.index = [ d[k] for k in list(df.index)]
df.style.bar(subset=["count"], color='#e5ae38')
# Out:
# <style type="text/css">
# #T_2b2d4_row0_col0, #T_2b2d4_row43_col0, #T_2b2d4_row46_col0, #T_2b2d4_row47_col0, #T_2b2d4_row48_col0, #T_2b2d4_row49_col0, #T_2b2d4_row54_col0, #T_2b2d4_row56_col0, #T_2b2d4_row58_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e5ae38 0.1%, transparent 0.1%);
# }
# #T_2b2d4_row1_col0, #T_2b2d4_row50_col0, #T_2b2d4_row51_col0, #T_2b2d4_row53_col0, #T_2b2d4_row55_col0, #T_2b2d4_row57_col0, #T_2b2d4_row59_col0, #T_2b2d4_row60_col0, #T_2b2d4_row61_col0, #T_2b2d4_row62_col0 {
#   width: 10em;
#   height: 80%;
# }
# #T_2b2d4_row2_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e5ae38 2.7%, transparent 2.7%);
# }
# #T_2b2d4_row3_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e5ae38 1.4%, transparent 1.4%);
# }
# #T_2b2d4_row4_col0, #T_2b2d4_row38_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e5ae38 1.1%, transparent 1.1%);
# }
# #T_2b2d4_row5_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e5ae38 4.9%, transparent 4.9%);
# }
# #T_2b2d4_row6_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e5ae38 8.4%, transparent 8.4%);
# }
# #T_2b2d4_row7_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e5ae38 16.3%, transparent 16.3%);
# }
# #T_2b2d4_row8_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e5ae38 23.4%, transparent 23.4%);
# }
# #T_2b2d4_row9_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e5ae38 56.1%, transparent 56.1%);
# }
# #T_2b2d4_row10_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e5ae38 74.7%, transparent 74.7%);
# }
# #T_2b2d4_row11_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e5ae38 100.0%, transparent 100.0%);
# }
# #T_2b2d4_row12_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e5ae38 85.9%, transparent 85.9%);
# }
# #T_2b2d4_row13_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e5ae38 95.8%, transparent 95.8%);
# }
# #T_2b2d4_row14_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e5ae38 83.7%, transparent 83.7%);
# }
# #T_2b2d4_row15_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e5ae38 77.6%, transparent 77.6%);
# }
# #T_2b2d4_row16_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e5ae38 80.6%, transparent 80.6%);
# }
# #T_2b2d4_row17_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e5ae38 60.9%, transparent 60.9%);
# }
# #T_2b2d4_row18_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e5ae38 51.9%, transparent 51.9%);
# }
# #T_2b2d4_row19_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e5ae38 47.8%, transparent 47.8%);
# }
# #T_2b2d4_row20_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e5ae38 32.6%, transparent 32.6%);
# }
# #T_2b2d4_row21_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e5ae38 19.5%, transparent 19.5%);
# }
# #T_2b2d4_row22_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e5ae38 20.9%, transparent 20.9%);
# }
# #T_2b2d4_row23_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e5ae38 18.3%, transparent 18.3%);
# }
# #T_2b2d4_row24_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e5ae38 12.0%, transparent 12.0%);
# }
# #T_2b2d4_row25_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e5ae38 13.7%, transparent 13.7%);
# }
# #T_2b2d4_row26_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e5ae38 10.1%, transparent 10.1%);
# }
# #T_2b2d4_row27_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e5ae38 9.9%, transparent 9.9%);
# }
# #T_2b2d4_row28_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e5ae38 6.3%, transparent 6.3%);
# }
# #T_2b2d4_row29_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e5ae38 4.6%, transparent 4.6%);
# }
# #T_2b2d4_row30_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e5ae38 5.7%, transparent 5.7%);
# }
# #T_2b2d4_row31_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e5ae38 3.2%, transparent 3.2%);
# }
# #T_2b2d4_row32_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e5ae38 2.5%, transparent 2.5%);
# }
# #T_2b2d4_row33_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e5ae38 2.3%, transparent 2.3%);
# }
# #T_2b2d4_row34_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e5ae38 1.5%, transparent 1.5%);
# }
# #T_2b2d4_row35_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e5ae38 1.2%, transparent 1.2%);
# }
# #T_2b2d4_row36_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e5ae38 1.0%, transparent 1.0%);
# }
# #T_2b2d4_row37_col0, #T_2b2d4_row41_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e5ae38 0.6%, transparent 0.6%);
# }
# #T_2b2d4_row39_col0, #T_2b2d4_row45_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e5ae38 0.7%, transparent 0.7%);
# }
# #T_2b2d4_row40_col0, #T_2b2d4_row44_col0, #T_2b2d4_row52_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e5ae38 0.2%, transparent 0.2%);
# }
# #T_2b2d4_row42_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e5ae38 0.9%, transparent 0.9%);
# }
# </style>
# <table id="T_2b2d4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >min</th>
#       <th class="col_heading level0 col2" >max</th>
#       <th class="col_heading level0 col3" >median</th>
#       <th class="col_heading level0 col4" >mean</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th class="col_heading level1 col0" >price_meter</th>
#       <th class="col_heading level1 col1" >price_meter</th>
#       <th class="col_heading level1 col2" >price_meter</th>
#       <th class="col_heading level1 col3" >price_meter</th>
#       <th class="col_heading level1 col4" >price_meter</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b2d4_level0_row0" class="row_heading level0 row0" >2000 - 3000 zl/m²</th>
#       <td id="T_2b2d4_row0_col0" class="data row0 col0" >2</td>
#       <td id="T_2b2d4_row0_col1" class="data row0 col1" >2211</td>
#       <td id="T_2b2d4_row0_col2" class="data row0 col2" >2578</td>
#       <td id="T_2b2d4_row0_col3" class="data row0 col3" >2394</td>
#       <td id="T_2b2d4_row0_col4" class="data row0 col4" >2394</td>
#     </tr>
#     <tr>
#       <th id="T_2b2d4_level0_row1" class="row_heading level0 row1" >3000 - 4000 zl/m²</th>
#       <td id="T_2b2d4_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_2b2d4_row1_col1" class="data row1 col1" >3805</td>
#       <td id="T_2b2d4_row1_col2" class="data row1 col2" >3805</td>
#       <td id="T_2b2d4_row1_col3" class="data row1 col3" >3805</td>
#       <td id="T_2b2d4_row1_col4" class="data row1 col4" >3805</td>
#     </tr>
#     <tr>
#       <th id="T_2b2d4_level0_row2" class="row_heading level0 row2" >4000 - 5000 zl/m²</th>
#       <td id="T_2b2d4_row2_col0" class="data row2 col0" >23</td>
#       <td id="T_2b2d4_row2_col1" class="data row2 col1" >4424</td>
#       <td id="T_2b2d4_row2_col2" class="data row2 col2" >4821</td>
#       <td id="T_2b2d4_row2_col3" class="data row2 col3" >4424</td>
#       <td id="T_2b2d4_row2_col4" class="data row2 col4" >4450</td>
#     </tr>
#     <tr>
#       <th id="T_2b2d4_level0_row3" class="row_heading level0 row3" >5000 - 6000 zl/m²</th>
#       <td id="T_2b2d4_row3_col0" class="data row3 col0" >12</td>
#       <td id="T_2b2d4_row3_col1" class="data row3 col1" >5037</td>
#       <td id="T_2b2d4_row3_col2" class="data row3 col2" >5937</td>
#       <td id="T_2b2d4_row3_col3" class="data row3 col3" >5557</td>
#       <td id="T_2b2d4_row3_col4" class="data row3 col4" >5533

# %% [markdown]
# ### ROOMS number

# %%
data = data.sort_values(by=['rooms'], ascending=False)  
sns.catplot(data=data, x="price", y="rooms", kind="box", height=5, aspect=3)
plt.xticks(list(range(0, int(max(data['price'])) + 100000, 100000)), rotation='vertical')
plt.title('Price / Rooms\n', fontweight='bold')
plt.savefig('WARSAW_rooms_price.png', bbox_inches='tight')
plt.show()

# %%
data = data.sort_values(by=['rooms'], ascending=False)  
sns.catplot(data=data, x="area", y="rooms", kind="box", height=5, aspect=3)
plt.xticks(list(range(0, int(max(data['area'])) + 10 , 10)), rotation='vertical')
plt.title('Size[m²] / Rooms\n', fontweight='bold')
plt.savefig('WARSAW_rooms_size.png', bbox_inches='tight')
plt.show()

# %%
data = data.sort_values(by=['rooms'], ascending=False)  
sns.catplot(data=data, x="price_meter", y="rooms", kind="box", height=5, aspect=3)
plt.xticks(list(range(0, int(max(data['price_meter'])) + 1000 , 1000)), rotation='vertical')
plt.title('Price[zl/m²] / Rooms\n', fontweight='bold')
plt.savefig('WARSAW_rooms_price_meter.png', bbox_inches='tight')
plt.show()

# %%
data.columns
# Out:
# Index(['free_text', 'address', 'price', 'price_meter', 'rooms', 'area', 'more',
#        'add_link', 'rooms_umber', 'LCBINS_100k', 'BINS_100k', 'LCBINS_10',
#        'BINS_10', 'LCBINS_1000SQ', 'BINS_10SQ'],
#       dtype='object')
